# %%
# !pip install numpy

# %%
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sales=pd.read_csv("C:/Users/Narasimmaraj/Downloads/Sales.csv")
sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
sales.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1   1/1/2016           NaN       265598        10
# 1        366001          1   1/1/2016     1/13/2016      1269051         0
# 2        366001          2   1/1/2016     1/13/2016      1269051         0
# 3        366002          1   1/1/2016     1/12/2016       266019         0
# 4        366002          2   1/1/2016     1/12/2016       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
sales.tail()
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 62879        43         632         3           USD
# 62880         0          98         4           EUR
# 62881         0        1613         2           CAD
# 62882         0        1717         2           CAD
# 62883         0         464         7           CAD

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
sales.shape
# Out:
# (62884, 9)

# %%
missing_value=sales.isnull().sum
missing_value()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
sales.columns
# Out:
# Index(['Order Number', 'Line Item', 'Order Date', 'Delivery Date',
#        'CustomerKey', 'StoreKey', 'ProductKey', 'Quantity', 'Currency Code'],
#       dtype='object')

# %%
# Drop column 'Delivery Date'
sales.drop(columns=['Delivery Date'], inplace=True)

print(sales)
# Out:
#        Order Number  Line Item  Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1  2016-01-01       265598        10        1304
# 1            366001          1  2016-01-01      1269051         0        1048
# 2            366001          2  2016-01-01      1269051         0        2007
# 3            366002          1  2016-01-01       266019         0        1106
# 4            366002          2  2016-01-01       266019         0         373
# ...             ...        ...         ...          ...       ...         ...
# 62879       2243030          1  2021-02-20      1216913        43         632
# 62880       2243031          1  2021-02-20       511229         0          98
# 62881       2243032          1  2021-02-20       331277         0        1613
# 62882       2243032          2  2021-02-20       331277         0        1717
# 62883       2243032          3  2021-02-20       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
sales["Order Date"] = pd.to_datetime (sales["Order Date"], errors='coerce').dt.date
sales
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01           NaN       265598
# 1            366001          1  2016-01-01     1/13/2016      1269051
# 2            366001          2  2016-01-01     1/13/2016      1269051
# 3            366002          1  2016-01-01     1/12/2016       266019
# 4            366002          2  2016-01-01     1/12/2016       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20           NaN      1216913
# 62880       2243031          1  2021-02-20     2/24/2021       511229
# 62881       2243032          1  2021-02-20     2/23/2021       331277
# 62882       2243032          2  2021-02-20     2/23/2021       331277
# 62883       2243032          3  2021-02-20     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
plt.figure(figsize=(10, 6))

sns.histplot(sales['Currency Code'].dropna(), kde=True, bins=20, color='skyblue')

plt.title('Distribution of Currency Code')

plt.xlabel('Currency Code')

plt.ylabel('Frequency')

plt.show()

# %%
# Count plot of app categories

plt.figure(figsize=(12, 6))

sns.countplot(y='Currency Code', data=sales, order = sales['Currency Code'].value_counts().index, palette='viridis')

plt.title('Count of Order Date')

plt.xlabel('Order Date')

plt.ylabel('Currency Code')

plt.show()
# Out:
# C:\Users\Narasimmaraj\AppData\Local\Temp\ipykernel_39832\1145002478.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Currency Code', data=sales, order = sales['Currency Code'].value_counts().index, palette='viridis')

# %%
#connecting with database
import mysql.connector
mydb = mysql.connector.connect(
 host="localhost",
 user="root",
 password="Nrnaidu@1",


)


print(mydb)
mycursor = mydb.cursor(buffered=True)

# %%
mycursor.execute("use project2")

# %%
mycursor.execute("create table sales (Order_Number INT PRIMARY KEY, Line_Item INT, Order_Date DATE, CustomerKey INT, StoreKey INT, ProductKey INT, Quantity INT, Currency_Code VARCHAR(10))")

# %%
sales
# Out:
#        Order Number  Line Item  Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1  2016-01-01       265598        10        1304
# 1            366001          1  2016-01-01      1269051         0        1048
# 2            366001          2  2016-01-01      1269051         0        2007
# 3            366002          1  2016-01-01       266019         0        1106
# 4            366002          2  2016-01-01       266019         0         373
# ...             ...        ...         ...          ...       ...         ...
# 62879       2243030          1  2021-02-20      1216913        43         632
# 62880       2243031          1  2021-02-20       511229         0          98
# 62881       2243032          1  2021-02-20       331277         0        1613
# 62882       2243032          2  2021-02-20       331277         0        1717
# 62883       2243032          3  2021-02-20       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
data_sales=sales.values.tolist()
insert_query = '''
INSERT INTO sales (Order_Number, Line_Item, Order_Date, CustomerKey, StoreKey,
       ProductKey, Quantity, Currency_Code)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
'''
for row in data_sales:
    mycursor.execute(insert_query,row)
mydb.commit()

# %%
insert_query = '''
INSERT IGNORE INTO sales (Order_Number, Line_Item, Order_Date, CustomerKey, StoreKey,
       ProductKey, Quantity, Currency_Code)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
'''

for row in data_sales:
    mycursor.execute(insert_query, row)

mydb.commit()

# %%
# import mysql.connector
# from mysql.connector import Error

# try:
#     # Connect to the MySQL database
#     connection = mysql.connector.connect(
#         host="localhost",
#         user="root",
#         password="Nrnaidu@1",
#         database='project3'
# )


#     if connection.is_connected():
#         cursor = connection.cursor()

#         # Corrected SQL statement to create table
#         create_table_query = '''
#         CREATE TABLE sales (
#             `Order Number` INT PRIMARY KEY,
#             `Line Item` INT,
#             `Order Date` DATE,
#             `CustomerKey` INT,
#             `StoreKey` INT,
#             `ProductKey` INT,
#             `Quantity` INT,
#             `Currency Code` VARCHAR(10)
#         )
#         '''

#         cursor.execute(create_table_query)
#         print("Table created successfully.")

# except Error as e:
#     print(f"Error: {e}")

# finally:
#     if connection.is_connected():
#         cursor.close()
#         connection.close()
#         print("MySQL connection is closed.")
# Out:
# Table created successfully.
# MySQL connection is closed.

# %%
import mysql.connector
from mysql.connector import Error

try:
    # Connect to the MySQL database
    connection = mysql.connector.connect(
        host="localhost",
        user="root",
        password="Nrnaidu@1",
        database='project3'
    )

    if connection.is_connected():
        cursor = connection.cursor()
        data_sales=sales.values.tolist()
        # SQL statement to insert data
        insert_query = '''
        INSERT INTO sales (`Order Number`, `Line Item`, `Order Date`, `CustomerKey`, `StoreKey`, `ProductKey`, `Quantity`, `Currency Code`)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
        '''
        
        # Assume data_products is a list of tuples
        # data_products = [
        #     (1, 'Product1', 'BrandA', 'Red', 10.00, 20.00, 101, 'Subcat1', 201, 'Cat1'),
        #     (2, 'Product2', 'BrandB', 'Blue', 15.00, 25.00, 102, 'Subcat2', 202, 'Cat2')
        #     # Add more tuples as needed
        # ]
        
        for row in data_sales:
            cursor.execute(insert_query, row)
        
        # Commit the transaction
        connection.commit()
        print("Data inserted successfully.")

except Error as e:
    print(f"Error: {e}")

finally:
    if connection.is_connected():
        cursor.close()
        connection.close()
        print("MySQL connection is closed.")
# Out:
# Error: 1062 (23000): Duplicate entry '366001' for key 'sales.PRIMARY'
# MySQL connection is closed.

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd  # Ensure pandas is imported if you're using DataFrames

try:
    # Connect to the MySQL database
    connection = mysql.connector.connect(
        host="localhost",
        user="root",
        password="Nrnaidu@1",
        database='project3'
    )

    if connection.is_connected():
        cursor = connection.cursor()

        # Assuming 'sales' is a pandas DataFrame
        # Ensure you have defined or imported 'sales' properly
        sales = sales.drop_duplicates(subset='Order Number')  # Drop duplicates based on primary key
        data_sales = sales.values.tolist()

        # SQL statement to insert data
        insert_query = '''
        INSERT INTO sales (`Order Number`, `Line Item`, `Order Date`, `CustomerKey`, `StoreKey`, `ProductKey`, `Quantity`, `Currency Code`)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
        ON DUPLICATE KEY UPDATE
        `Line Item` = VALUES(`Line Item`),
        `Order Date` = VALUES(`Order Date`),
        `CustomerKey` = VALUES(`CustomerKey`),
        `StoreKey` = VALUES(`StoreKey`),
        `ProductKey` = VALUES(`ProductKey`),
        `Quantity` = VALUES(`Quantity`),
        `Currency Code` = VALUES(`Currency Code`)
        '''

        # Insert each row of data
        for row in data_sales:
            cursor.execute(insert_query, row)

        # Commit the transaction
        connection.commit()
        print("Data inserted successfully.")

except Error as e:
    print(f"Error: {e}")

finally:
    if connection.is_connected():
        cursor.close()
        connection.close()
        print("MySQL connection is closed.")
# Out:
# Data inserted successfully.
# MySQL connection is closed.
