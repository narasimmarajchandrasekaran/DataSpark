# %%
# !pip install seaborn

# %%
# import pandas as pd

# # Try different encodings
# try:
# customers = pd.read_csv("C:/Users/Narasimmaraj/Downloads/Customers.csv", encoding='utf-8')
# except UnicodeDecodeError:
#     try:
#     customers = pd.read_csv("C:/Users/Narasimmaraj/Downloads/Customers.csv", encoding='ISO-8859-1')
#     except UnicodeDecodeError:
#     customers = pd.read_csv("C:/Users/Narasimmaraj/Downloads/Customers.csv", encoding='windows-1252')

# # Display the first few rows of the DataFrame
# print(customers)
import pandas as pd

# Try different encodings
try:
    customers = pd.read_csv("C:/Users/Narasimmaraj/Downloads/Customers.csv", encoding='utf-8')
except UnicodeDecodeError:
    try:
        customers = pd.read_csv("C:/Users/Narasimmaraj/Downloads/Customers.csv", encoding='ISO-8859-1')
    except UnicodeDecodeError:
        customers = pd.read_csv("C:/Users/Narasimmaraj/Downloads/Customers.csv", encoding='windows-1252')

# Display the first few rows of the DataFrame
print(customers)
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
customers.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia    7/3/1939
# 1  Western Australia     6522  Australia  Australia   9/27/1979
# 2           Victoria     3380  Australia  Australia   5/26/1947
# 3    South Australia     5223  Australia  Australia   9/17/1957
# 4           Victoria     3698  Australia  Australia  11/19/1965

# %%
customers.tail()
# Out:
#        CustomerKey  Gender              Name                 City State Code  \
# 15261      2099600  Female    Denisa Duková              Houston         TX
# 15262      2099618    Male  Justin Solórzano               Mclean         VA
# 15263      2099758    Male   Svend Petrussen           Wilmington         NC
# 15264      2099862  Female      Lorenza Rush            Riverside         CA
# 15265      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
#
#                 State Zip Code        Country      Continent    Birthday
# 15261           Texas    77017  United States  North America   3/25/1936
# 15262        Virginia    22101  United States  North America   2/16/1992
# 15263  North Carolina    28405  United States  North America   11/9/1937
# 15264      California    92501  United States  North America  10/12/1937
# 15265        Michigan    48302  United States  North America   8/18/1965

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
customers.shape
# Out:
# (15266, 10)

# %%
missing_value=customers.isnull().sum
missing_value()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.drop_duplicates(inplace=True)

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.shape
# Out:
# (15266, 10)

# %%
customers.columns
# Out:
# Index(['CustomerKey', 'Gender', 'Name', 'City', 'State Code', 'State',
#        'Zip Code', 'Country', 'Continent', 'Birthday'],
#       dtype='object')

# %%
# Drop column 'State Code'
customers.drop(columns=['State Code'], inplace=True)

print(customers)
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Duková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State Zip Code        Country      Continent    Birthday
# 0        South Australia     5523      Australia      Australia    7/3/1939
# ...

# %%
customers
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Duková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State Zip Code        Country      Continent    Birthday
# 0        South Australia     5523      Australia      Australia    7/3/1939
# ...

# %%
missing_value=customers.isnull().sum
missing_value()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
customers.describe()
# Out:
#         CustomerKey
# count  1.526600e+04
# mean   1.060508e+06
# std    6.127097e+05
# min    3.010000e+02
# 25%    5.140335e+05
# 50%    1.079244e+06
# 75%    1.593980e+06
# max    2.099937e+06

# %%
customers.describe(include='object')
# Out:
#        Gender        Name     City       State Zip Code        Country  \
# count   15266       15266    15266       15266    15266          15266
# unique      2       15118     8258         512     9505              8
# top      Male  John Smith  Toronto  California    90017  United States
# freq     7748           4      204         715       70           6828
#
#             Continent   Birthday
# count           15266      15266
# unique              3      11270
# top     North America  5/29/1965
# freq             8381          5

# %%
customers.describe(include='object').T
# Out:
#            count unique            top  freq
# Gender     15266      2           Male  7748
# Name       15266  15118     John Smith     4
# City       15266   8258        Toronto   204
# State      15266    512     California   715
# Zip Code   15266   9505          90017    70
# Country    15266      8  United States  6828
# Continent  15266      3  North America  8381
# Birthday   15266  11270      5/29/1965     5

# %%
customers["Birthday"] = pd.to_datetime (customers["Birthday"], errors='coerce').dt.date
customers
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Duková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State Zip Code        Country      Continent    Birthday
# 0        South Australia     5523      Australia      Australia  1939-07-03
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))

sns.histplot(customers['Country'].dropna(), kde=True, bins=20, color='skyblue')

plt.title('Distribution of Country')

plt.xlabel('Country')

plt.ylabel('Frequency')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create the boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='CustomerKey', data=df, color='skyblue')

# Set the title and labels
plt.title('Distribution of customers')
plt.xlabel('CustomerKey')

# Show the plot
plt.show()

# %%
#connecting with database
import mysql.connector
mydb = mysql.connector.connect(
 host="localhost",
 user="root",
 password="Nrnaidu@1",


)


print(mydb)
mycursor = mydb.cursor(buffered=True)

# %%
mycursor.execute("use project2")

# %%
mycursor.execute("create table customer (customerkey int, gender varchar(400),name varchar(400),city varchar(400),state varchar(200),zipcode varchar(200),country varchar(200),continent varchar(200),birthday varchar(200))")

# %%
data_customer = customers.values.tolist()
insert_query = '''
INSERT INTO customer(customerkey, gender, name, city, state, zipcode, country, continent, birthday)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
'''
for row in data_customer:
    mycursor.execute(insert_query,row)
mydb.commit()
